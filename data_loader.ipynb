# %%
import yfinance as fy

# %%
data = fy.Ticker("AAPL",)
data.info
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '(408) 996-1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
data.calendar
# Out:
# {'Dividend Date': datetime.date(2025, 5, 15),
#  'Ex-Dividend Date': datetime.date(2025, 5, 12),
#  'Earnings Date': [datetime.date(2025, 7, 30), datetime.date(2025, 8, 4)],
#  'Earnings High': 1.51,
#  'Earnings Low': 1.34,
#  'Earnings Average': 1.42415,
#  'Revenue High': 90104000000,
#  'Revenue Low': 86919000000,
#  'Revenue Average': 88638880990}

# %%
data.analyst_price_targets
# Out:
# {'current': 201.08,
#  'high': 300.0,
#  'low': 170.62,
#  'mean': 228.60326,
#  'median': 230.0}

# %%
data.quarterly_incomestmt
# Out:
#                                                        2025-03-31  \
# Tax Effect Of Unusual Items                                   0.0
# Tax Rate For Calcs                                          0.155
# Normalized EBITDA                                   32250000000.0
# Net Income From Continuing Operation Net Minori...  24780000000.0
# Reconciled Depreciation                              2661000000.0
# Reconciled Cost Of Revenue                          50492000000.0
# EBITDA                                              32250000000.0
# EBIT                                                29589000000.0
# Net Interest Income                                           NaN
# Interest Expense                                              NaN
# Interest Income                                               NaN
# Normalized Income                                   24780000000.0
# Net Income From Continuing And Discontinued Ope...  24780000000.0
# ...

# %%
data.history(period="6mo")
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-05-28 00:00:00-04:00  200.589996  202.729996  199.899994  200.419998
# 2025-05-29 00:00:00-04:00  203.580002  203.809998  198.509995  199.949997
# 2025-05-30 00:00:00-04:00  199.369995  201.960007  196.779999  200.850006
# 2025-06-02 00:00:00-04:00  200.279999  202.130005  200.119995  201.699997
# 2025-06-03 00:00:00-04:00  201.350006  203.770004  200.960007  203.270004
# 2025-06-04 00:00:00-04:00  202.910004  206.240005  202.100006  202.820007
# 2025-06-05 00:00:00-04:00  203.500000  204.750000  200.149994  200.630005
# 2025-06-06 00:00:00-04:00  203.000000  205.699997  202.050003  203.919998
# 2025-06-09 00:00:00-04:00  204.389999  206.000000  200.020004  201.449997
# 2025-06-10 00:00:00-04:00  200.600006  204.350006  200.570007  202.669998
# 2025-06-11 00:00:00-04:00  203.500000  204.500000  198.410004  198.779999
# 2025-06-12 00:00:00-04:00  199.080002  199.679993  197.360001  199.199997
# ...

# %%
fy.download(['MSFT'],period="1mo")
# Out:
# C:\Users\Aman\AppData\Local\Temp\ipykernel_11892\2624757769.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   fy.download(['MSFT'],period="2mo")
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker            MSFT        MSFT        MSFT        MSFT      MSFT
# Date
# 2025-04-28  390.443207  392.020298  385.931501  391.241729  16579400
# 2025-04-29  393.317932  394.375987  389.664635  390.582932  14974000
# 2025-04-30  394.535706  395.933134  383.735526  389.584773  36461100
# 2025-05-01  424.620453  436.189211  424.121369  430.319981  58938100
# 2025-05-02  434.482361  438.634741  429.202046  430.948839  30757400
# 2025-05-05  435.370728  438.694612  431.318140  432.076757  20136100
# 2025-05-06  432.515961  436.927874  430.379898  431.408009  15104200
# 2025-05-07  432.555908  437.317156  430.319992  433.045001  23295300
# ...
